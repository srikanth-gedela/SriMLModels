# %% [markdown]
# <h2 align=center>Introduction to Anomaly Detection in Time Series with Keras</h2>

# %% [markdown]
# ## Task 1: Project Overview and Import Libraries

# %%
import numpy as np
import tensorflow as tf
import pandas as pd
pd.options.mode.chained_assignment = None
import seaborn as sns
from matplotlib.pylab import rcParams
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go

# %matplotlib inline

sns.set(style='whitegrid', palette='muted')
rcParams['figure.figsize'] = 14, 8
np.random.seed(1)
tf.random.set_seed(1)

print('Tensorflow version:', tf.__version__)
# Out:
# Tensorflow version: 2.1.0

# %% [markdown]
# ## Task 2: Load and Inspect the S&P 500 Index Data

# %% [markdown]
# [Data Source](https://www.kaggle.com/pdquant/sp500-daily-19862018): S&P500 Daily Prices 1986 - 2018

# %%
df = pd.read_csv('./S&P_500_Index_Data.csv')

# %%
df.head()
# Out:
#         date   close
# 0  02-Jan-86  209.59
# 1  03-Jan-86  210.88
# 2  06-Jan-86  210.65
# 3  07-Jan-86  213.80
# 4  08-Jan-86  207.97

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8192 entries, 0 to 8191
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   date    8192 non-null   object
#  1   close   8192 non-null   float64
# dtypes: float64(1), object(1)
# memory usage: 128.1+ KB

# %%
df.describe()
# Out:
#              close
# count  8192.000000
# mean   1070.897411
# std     616.714534
# min     203.490000
# 25%     458.632500
# 50%    1106.435000
# 75%    1388.132500
# max    2872.870000

# %%
df.shape
# Out:
# (8192, 2)

# %%
fig=go.Figure()
fig.add_trace(go.Scatter(x=df.date, y=df.close, mode='lines', name='close'))
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="75bd72f9-16db-45e7-9abf-74c51d099949" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("75bd72f9-16db-45e7-9abf-74c51d099949")) {
#                     Plotly.newPlot(
#                         '75bd72f9-16db-45e7-9abf-74c51d099949',
#                         [{"mode": "lines", "name": "close", "type": "scatter", "x": ["02-Jan-86", "03-Jan-86", "06-Jan-86", "07-Jan-86", "08-Jan-86", "09-Jan-86", "10-Jan-86", "13-Jan-86", "14-Jan-86", "15-Jan-86", "16-Jan-86", "17-Jan-86", "20-Jan-86", "21-Jan-86", "22-Jan-86", "23-Jan-86", "24-Jan-86", "27-Jan-86", "28-Jan-86", "29-Jan-86", "30-Jan-86", "31-Jan-86", "03-Feb-86", "04-Feb-86", "05-Feb-86", "06-Feb-86", "07-Feb-86", "10-Feb-86", "11-Feb-86", "12-Feb-86", "13-Feb-86", "14-Feb-86", "18-Feb-86", "19-Feb-86", "20-Feb-86", "21-Feb-86", "24-Feb-86", "25-Feb-86", "26-Feb-86", "27-Feb-86", "28-Feb-86", "03-Mar-86", "04-Mar-86", "05-Mar-86", "06-Mar-86", "07-Mar-86", "10-Mar-86", "11-Mar-86", "12-Mar-86", "13-Mar-86", "14-Mar-86", "17-Mar-86", "18-Mar-86", "19-Mar-86", "20-Mar-86", "21-Mar-86", "24-Mar-86", "25-Mar-86", "26-Mar-86", "27-Mar-86", "31-Mar-86", "01-Apr-86", "02-Apr-86", "03-Apr-86", "04-Apr-86", "07-Apr-86", "08-Apr-86", "09-Apr-86", "10-Apr-86", "11-Apr-86", "14-Apr-86", "15-Apr-86", "16-Apr-86", "17-Apr-86", "18-Apr-86", "21-Apr-86", "22-Apr-86", "23-Apr-86", "24-Apr-86", "25-Apr-86", "28-Apr-86", "29-Apr-86", "30-Apr-86", "01-May-
-Jan-87", "22-Jan-87", "23-Jan-87", "26-Jan-87", "27-Jan-87", "28-Jan-87", "29-Jan-87", "30-Jan-87", "02-Feb-87", "03-Feb-87", "04-Feb-87", "05-Feb-87", "06-Feb-87", "09-Feb-87", "10-Feb-87", "11-Feb-87", "12-Feb-87", "13-Feb-87", "17-Feb-87", "18-Feb-87", "19-Feb-87", "20-Feb-87", "23-Feb-87", "24-Feb-87", "25-Feb-87", "26-Feb-87", "27-Feb-87", "02-Mar-87", "03-Mar-87", "04-Mar-87", "05-Mar-87", "06-Mar-87", "09-Mar-87", "10-Mar-87", "11-Mar-87", "1 ...

# %% [markdown]
# ## Task 3: Data Preprocessing

# %%
train_size=int(len(df)*0.8)
test_size = len(df) - train_size
train, test = df.iloc[0:train_size], df.iloc[train_size:len(df)]
print(train.shape, test.shape)
# Out:
# (6553, 2) (1639, 2)

# %%
from sklearn.preprocessing import StandardScaler

scaler =StandardScaler()
scaler = scaler.fit(train[['close']])

train['close'] = scaler.transform(train[['close']])
test['close'] = scaler.transform(test[['close']])

# %%
#Close data after scaling 
fig=go.Figure()
fig.add_trace(go.Scatter(x=train.date, y=train.close, mode='lines', name='close'))
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="9c9c731d-0e31-4bf5-9b4f-0e4da848f49e" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9c9c731d-0e31-4bf5-9b4f-0e4da848f49e")) {
#                     Plotly.newPlot(
#                         '9c9c731d-0e31-4bf5-9b4f-0e4da848f49e',
#                         [{"mode": "lines", "name": "close", "type": "scatter", "x": ["02-Jan-86", "03-Jan-86", "06-Jan-86", "07-Jan-86", "08-Jan-86", "09-Jan-86", "10-Jan-86", "13-Jan-86", "14-Jan-86", "15-Jan-86", "16-Jan-86", "17-Jan-86", "20-Jan-86", "21-Jan-86", "22-Jan-86", "23-Jan-86", "24-Jan-86", "27-Jan-86", "28-Jan-86", "29-Jan-86", "30-Jan-86", "31-Jan-86", "03-Feb-86", "04-Feb-86", "05-Feb-86", "06-Feb-86", "07-Feb-86", "10-Feb-86", "11-Feb-86", "12-Feb-86", "13-Feb-86", "14-Feb-86", "18-Feb-86", "19-Feb-86", "20-Feb-86", "21-Feb-86", "24-Feb-86", "25-Feb-86", "26-Feb-86", "27-Feb-86", "28-Feb-86", "03-Mar-86", "04-Mar-86", "05-Mar-86", "06-Mar-86", "07-Mar-86", "10-Mar-86", "11-Mar-86", "12-Mar-86", "13-Mar-86", "14-Mar-86", "17-Mar-86", "18-Mar-86", "19-Mar-86", "20-Mar-86", "21-Mar-86", "24-Mar-86", "25-Mar-86", "26-Mar-86", "27-Mar-86", "31-Mar-86", "01-Apr-86", "02-Apr-86", "03-Apr-86", "04-Apr-86", "07-Apr-86", "08-Apr-86", "09-Apr-86", "10-Apr-86", "11-Apr-86", "14-Apr-86", "15-Apr-86", "16-Apr-86", "17-Apr-86", "18-Apr-86", "21-Apr-86", "22-Apr-86", "23-Apr-86", "24-Apr-86", "25-Apr-86", "28-Apr-86", "29-Apr-86", "30-Apr-86", "01-May-86", "02-May-86", "05-May-86", "06-May-86", "07-May-86", "08-May-86", "09-May-86", "12-May-86", "13-May-86", "14-May-86",
jan-87", "02-Feb-87", "03-Feb-87", "04-Feb-87", "05-Feb-87", "06-Feb-87", "09-Feb-87", "10-Feb-87", "11-Feb-87", "12-Feb-87", "13-Feb-87", "17-Feb-87", "18-Feb-87", "19-Feb-87", "20-Feb-87", "23-Feb-87", "24-Feb-87", "25-Feb-87", "26-Feb-87", "27-Feb-87", "02-Mar-87", "03-Mar-87", "04-Mar-87", "05-Mar-87", "06-Mar-87", "09-Mar-87", "10-Mar-87", "11-Mar-87", "1 ...

# %% [markdown]
# ## Task 4: Create Training and Test Splits

# %%
train[['close']].iloc[1:31].values
# Out:
# array([[-1.51302665],
#        [-1.51357786],
#        [-1.50602867],
#        [-1.52000066],
#        [-1.52445828],
#        [-1.52481777],
#        [-1.52299637],
#        [-1.5231881 ],
#        [-1.51930566],
#        [-1.51712478],
#        [-1.51889824],
#        [-1.52105515],
#        [-1.52522518],
#        [-1.53073729],
#        [-1.5289159 ],
#        [-1.52369138],
#        [-1.52139067],
#        [-1.51559098],
#        [-1.51444063],
#        [-1.51674133],
#        [-1.51086974],
#        [-1.50564522],
#        [-1.50844921],
#        [-1.50804179],
#        [-1.50681954],
#        [-1.50420728],
#        [-1.50018105],
#        [-1.50094795],
#        [-1.50082812],
#        [-1.49740103]])

# %%
# Temoralize Data and Create Training & test Splits 
# LSTM input layer must be 3d (samples, timesteps, features)
def create_sequences(X, y, time_steps=1):
    Xs, ys = [], []
    for i in range(len(X) - time_steps):
        Xs.append(X.iloc[i:(i+time_steps)].values)
        ys.append(y.iloc[i+time_steps])
    return np.array(Xs), np.array(ys)

# %%
time_steps =30
X_train, y_train = create_sequences(train[['close']], train.close, time_steps)
X_test, y_test = create_sequences(test[['close']], test.close, time_steps)

# %%
print(X_train.shape)
# Out:
# (6523, 30, 1)

# %%
print(X_train)
# Out:
# [[[-1.51611822]
#   [-1.51302665]
#   [-1.51357786]
#   ...
#   [-1.50018105]
#   [-1.50094795]
#   [-1.50082812]]
#
#  [[-1.51302665]
#   [-1.51357786]
#   [-1.50602867]
#   ...
#   [-1.50094795]
#   [-1.50082812]
#   [-1.49740103]]
#
#  [[-1.51357786]
#   [-1.50602867]
#   [-1.52000066]
#   ...
#   [-1.50082812]
#   [-1.49740103]
#   [-1.49174513]]
#
#  ...
#
#  [[ 1.00394471]
#   [ 1.03941391]
#   [ 0.92720661]
#   ...
#   [ 0.89521243]
#   [ 0.90458301]
#   [ 0.87028812]]
#
#  [[ 1.03941391]
#   [ 0.92720661]
#   [ 0.95258626]
#   ...
#   [ 0.90458301]
#   [ 0.87028812]
#   [ 0.95644473]]
#
#  [[ 0.92720661]
#   [ 0.95258626]
#   [ 1.01048734]
#   ...
#   [ 0.87028812]
#   [ 0.95644473]
#   [ 0.96224443]]]

# %% [markdown]
# ## Task 5: Build an LSTM Autoencoder

# %%
timesteps=X_train.shape[1]
num_features =X_train.shape[2]
print(timesteps, num_features)
# Out:
# 30 1

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, LSTM, Dropout, RepeatVector, TimeDistributed

model= Sequential([
    LSTM(128, input_shape=(timesteps, num_features)),
    Dropout(0.2),
    RepeatVector(timesteps),
    LSTM(128, return_sequences=True),
    Dropout(0.2),
    TimeDistributed(Dense(num_features))
])

model.compile(loss='mae', optimizer='adam')
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# lstm_2 (LSTM)                (None, 128)               66560
# _________________________________________________________________
# dropout_2 (Dropout)          (None, 128)               0
# _________________________________________________________________
# repeat_vector_1 (RepeatVecto (None, 30, 128)           0
# _________________________________________________________________
# lstm_3 (LSTM)                (None, 30, 128)           131584
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 30, 128)           0
# _________________________________________________________________
# time_distributed_1 (TimeDist (None, 30, 1)             129
# =================================================================
# Total params: 198,273
# Trainable params: 198,273
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ## Task 6: Train the Autoencoder

# %%
es = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=3, mode='min')
history = model.fit(
    X_train, y_train,
    epochs=100,
    batch_size=32,
    validation_split=0.1,
    callbacks=[es],
    shuffle=False
)
# Out:
# Train on 5870 samples, validate on 653 samples
# Epoch 1/100
# 5870/5870 [==============================] - 21s 4ms/sample - loss: 0.1625 - val_loss: 0.1610
# Epoch 2/100
# 5870/5870 [==============================] - 17s 3ms/sample - loss: 0.1114 - val_loss: 0.0986
# Epoch 3/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0903 - val_loss: 0.0443
# Epoch 4/100
# 5870/5870 [==============================] - 17s 3ms/sample - loss: 0.0802 - val_loss: 0.0442
# Epoch 5/100
# 5870/5870 [==============================] - 19s 3ms/sample - loss: 0.0717 - val_loss: 0.0618
# Epoch 6/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0774 - val_loss: 0.0326
# Epoch 7/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0751 - val_loss: 0.0309
# Epoch 8/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0745 - val_loss: 0.0590
# Epoch 9/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0759 - val_loss: 0.0528
# Epoch 10/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0766 - val_loss: 0.0304
# Epoch 11/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0735 - val_loss: 0.0596
# Epoch 12/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0749 - val_loss: 0.0646
# Epoch 13/100
# 5870/5870 [==============================] - 16s 3ms/sample - loss: 0.0752 - val_loss: 0.0276
# Epoch 14/100
# 5870/5870 [==============================] - 17s 3ms/sample - loss: 0.0746 - val_loss: 0.0404
# Epoch 15/100
# 5870/5870 [==============================] - 19s 3ms/sample - loss: 0.0740 - val_loss: 0.0443
# Epoch 16/100
# 5870/5870 [==============================] - 18s 3ms/sample - loss: 0.0760 - val_loss: 0.0278

# %% [markdown]
# ## Task 7: Plot Metrics and Evaluate the Model

# %%
plt.plot(history.history['loss'], label='Training loss')
plt.plot(history.history['val_loss'], label='Validation loss')
plt.legend();

# %%
X_train_pred = model.predict(X_train)
train_mae_loss = pd.DataFrame(np.mean(np.abs(X_train_pred - X_train), axis=1), columns=['Error'])

# %%
model.evaluate(X_test, y_test)
# Out:
# 1609/1609 [==============================] - 1s 865us/sample - loss: 0.2708
# 0.270815260740746

# %%
sns.distplot(train_mae_loss, bins=50, kde=True)

# %%
threshold=0.65

# %%
X_test_pred= model.predict(X_test)
test_mae_loss = np.mean(np.abs(X_test_pred - X_test), axis=1)

# %% [markdown]
# ## Task 8: Detect Anomalies in the S&P 500 Index Data

# %%
test_score_df = pd.DataFrame(test[time_steps:])
test_score_df['loss'] = test_mae_loss
test_score_df['threshold'] = threshold
test_score_df['anomaly'] = test_score_df.loss>test_score_df.threshold
test_score_df['close']=test[time_steps:].close

# %%
test_score_df.head()
# Out:
#            date     close      loss  threshold  anomaly
# 6583  08-Feb-12  1.216856  0.094082       0.65    False
# 6584  09-Feb-12  1.221625  0.093309       0.65    False
# 6585  10-Feb-12  1.199313  0.091045       0.65    False
# 6586  13-Feb-12  1.221194  0.073555       0.65    False
# 6587  14-Feb-12  1.218150  0.075310       0.65    False

# %%
test_score_df.tail()
# Out:
#            date     close      loss  threshold  anomaly
# 8187  25-Jun-18  4.493228  0.646861       0.65    False
# 8188  26-Jun-18  4.507583  0.699449       0.65     True
# 8189  27-Jun-18  4.451431  0.704458       0.65     True
# 8190  28-Jun-18  4.491406  0.735130       0.65     True
# 8191  29-Jun-18  4.496343  0.717321       0.65     True

# %%
test_score_df['anomaly'].value_counts()
# Out:
# False    1562
# True       47
# Name: anomaly, dtype: int64

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=test[time_steps:].date, y=test_score_df.loss,
                         mode='lines', name='Test Loss'))
fig.add_trace(go.Scatter(x=test[time_steps:].date, y=test_score_df.threshold,
                         mode='lines', name='Threshold'))
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="b4ed9efa-6dad-473c-986f-54366aec4291" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b4ed9efa-6dad-473c-986f-54366aec4291")) {
#                     Plotly.newPlot(
#                         'b4ed9efa-6dad-473c-986f-54366aec4291',
#                         [{"mode": "lines", "name": "Test Loss", "type": "scatter", "x": ["08-Feb-12", "09-Feb-12", "10-Feb-12", "13-Feb-12", "14-Feb-12", "15-Feb-12", "16-Feb-12", "17-Feb-12", "21-Feb-12", "22-Feb-12", "23-Feb-12", "24-Feb-12", "27-Feb-12", "28-Feb-12", "29-Feb-12", "01-Mar-12", "02-Mar-12", "05-Mar-12", "06-Mar-12", "07-Mar-12", "08-Mar-12", "09-Mar-12", "12-Mar-12", "13-Mar-12", "14-Mar-12", "15-Mar-12", "16-Mar-12", "19-Mar-12", "20-Mar-12", "21-Mar-12", "22-Mar-12", "23-Mar-12", "26-Mar-12", "27-Mar-12", "28-Mar-12", "29-Mar-12", "30-Mar-12", "02-Apr-12", "03-Apr-12", "04-Apr-12", "05-Apr-12", "09-Apr-12", "10-Apr-12", "11-Apr-12", "12-Apr-12", "13-Apr-12", "16-Apr-12", "17-Apr-12", "18-Apr-12", "19-Apr-12", "20-Apr-12", "23-Apr-12", "24-Apr-12", "25-Apr-12", "26-Apr-12", "27-Apr-12", "30-Apr-12", "01-May-12", "02-May-12", "03-May-12", "04-May-12", "07-May-12", "08-May-12", "09-May-12", "10-May-12", "11-May-12", "14-May-12", "15-May-12", "16-May-12", "17-May-12", "18-May-12", "21-May-12", "22-May-12", "23-May-12", "24-May-12", "25-May-12", "29-May-12", "30-May-12", "31-May-12", "01-Jun-12", "04-Jun-12", "05-Jun-12", "06-Jun-12", "07-Jun-12", "08-Jun-12", "11-Jun-12", "12-Jun-12", "13-Jun-12", "14-Jun-12", "15-Jun-12", "18-Jun-12", "19-Jun-12", "20-Jun-12", "21-Jun-12", "22-Jun-12", "25-Jun-12", "26-Jun-12", "27-Jun-12", "28-Jun-12", "29-Jun-12", "02-Jul-12", "03-Jul-12", "05-Jul-12", "06-Jul-12", "09-Jul-12", "10-Jul-12", "11-Jul-12", "12-Jul-12", "13-Jul-12", "16-Jul-12", "17-Jul-12", "18-Jul-12", "19-Jul-12", "20-Jul-12", "23-Jul-12", "24-Jul-12", "25-Jul-12", "26-Jul-12", "27-Jul-12", "30-Jul-12", "31-Jul-12", "01-Aug-12", "02-A
# %%
anomalies =test_score_df[test_score_df.anomaly==True]
anomalies.head()
# Out:
#            date     close      loss  threshold  anomaly
# 7474  25-Aug-15  2.457439  0.655632       0.65     True
# 7475  26-Aug-15  2.632149  0.711593       0.65     True
# 8090  05-Feb-18  4.329949  0.665444       0.65     True
# 8091  06-Feb-18  4.440671  0.853328       0.65     True
# 8092  07-Feb-18  4.408365  0.829433       0.65     True

# %%
fig =go.Figure()
fig.add_trace(go.Scatter(x=test[time_steps:].date, y=scaler.inverse_transform(test[time_steps:].close),
                         mode='lines', name='Close Price'))
fig.add_trace(go.Scatter(x=anomalies.date, y=scaler.inverse_transform(anomalies.close),
                         mode='markers', name='Anomaly'))
fig.update_layout(showlegend=True)
fig.show()
# Out:
# <div>
#
#
#             <div id="b3a8d614-239d-4c0e-8379-d89eca25dbb2" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#                 require(["plotly"], function(Plotly) {
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("b3a8d614-239d-4c0e-8379-d89eca25dbb2")) {
#                     Plotly.newPlot(
#                         'b3a8d614-239d-4c0e-8379-d89eca25dbb2',
#                         [{"mode": "lines", "name": "Close Price", "type": "scatter", "x": ["08-Feb-12", "09-Feb-12", "10-Feb-12", "13-Feb-12", "14-Feb-12", "15-Feb-12", "16-Feb-12", "17-Feb-12", "21-Feb-12", "22-Feb-12", "23-Feb-12", "24-Feb-12", "27-Feb-12", "28-Feb-12", "29-Feb-12", "01-Mar-12", "02-Mar-12", "05-Mar-12", "06-Mar-12", "07-Mar-12", "08-Mar-12", "09-Mar-12", "12-Mar-12", "13-Mar-12", "14-Mar-12", "15-Mar-12", "16-Mar-12", "19-Mar-12", "20-Mar-12", "21-Mar-12", "22-Mar-12", "23-Mar-12", "26-Mar-12", "27-Mar-12", "28-Mar-12", "29-Mar-12", "30-Mar-12", "02-Apr-12", "03-Apr-12", "04-Apr-12", "05-Apr-12", "09-Apr-12", "10-Apr-12", "11-Apr-12", "12-Apr-12", "13-Apr-12", "16-Apr-12", "17-Apr-12", "18-Apr-12", "19-Apr-12", "20-Apr-12", "23-Apr-12", "24-Apr-12", "25-Apr-12", "26-Apr-12", "27-Apr-12", "30-Apr-12", "01-May-12", "02-May-12", "03-May-12", "04-May-12", "07-May-12", "08-May-12", "09-May-12", "10-May-12", "11-May-12", "14-May-12", "15-May-12", "16-May-12", "17-May-12", "18-May-12", "21-May-12", "22-May-12", "23-May-12", "24-May-12", "25-May-12", "29-May-12", "30-May-12", "31-May-12", "01-Jun-12", "04-Jun-12", "05-Jun-12", "06-Jun-12", "07-Jun-12", "08-Jun-12", "11-Jun-12", "12-Jun-12", "13-Jun-12", "14-Jun-12", "15-Jun-12", "18-Jun-12", "19-Jun-12", "20-Jun-12", "21-Jun-12", "22-Jun-12", "25-Jun-12", "26-Jun-12", "27-Jun-12", "28-Jun-12", "29-Jun-12", "02-Jul-12", "03-Jul-12", "05-Jul-12", "06-Jul-12", "09-Jul-12", "10-Jul-12", "11-Jul-12", "12-Jul-12", "13-Jul-12", "16-Jul-12", "17-Jul-12", "18-Jul-12", "19-Jul-12", "20-Jul-12", "23-Jul-12", "24-Jul-12", "25-Jul-12", "26-Jul-12", "27-Jul-12", "30-Jul-12", "31-Jul-12", "01-Aug-12", "02-Aug-12", "03