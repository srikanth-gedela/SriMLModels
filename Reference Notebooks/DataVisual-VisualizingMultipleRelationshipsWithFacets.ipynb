# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
automobile_data_processed = pd.read_csv('datasets/automobile_data_processed.csv')

automobile_data_processed.sample(5)
# Out:
#      symboling  normalized-losses    make fuel-type aspiration num-of-doors  \
# 117          0               91.0  toyota    diesel        std         four
# 81           0              161.0  peugot       gas        std         four
# 31           1              107.0   honda       gas        std          two
# 29           0               85.0   honda       gas        std         four
# 36           1              113.0   mazda       gas        std         four
#
#     body-style drive-wheels engine-location  wheel-base  ...  engine-size  \
# 117      sedan          fwd           front        95.7  ...          110
# 81       sedan          rwd           front       107.9  ...          120
# 31       sedan          fwd           front        96.5  ...          110
# 29       sedan          fwd           front        96.5  ...          110
# 36       sedan          fwd           front        93.1  ...           91
#
#      fuel-system  bore  stroke compression-ratio horsepower  peak-rpm  \
# 117          idi  3.27    3.35              22.5       56.0    4500.0
# 81          mpfi  3.46    3.19               8.4       97.0    5000.0
# 31          2bbl  3.15    3.58               9.1      100.0    5500.0
# 29          1bbl  3.15    3.58               9.0       86.0    5800.0
# 36          2bbl  3.03    3.15               9.0       68.0    5000.0
#
#     city-mpg  highway-mpg    price
# 117       34           36   7898.0
# 81        19           24  16630.0
# 31        25           31  10345.0
# 29        27           33  10295.0
# 36        31           38   6695.0
#
# [5 rows x 26 columns]

# %% [markdown]
# * We can see the price according to the number of fuel type

# %%
plt.figure(figsize=(15,10))

fg = sns.FacetGrid(automobile_data_processed, 
                   col='fuel-type', 
                   height=7, aspect=1)

fg.map(plt.hist, 'price', color='red')

plt.show()

# %% [markdown]
# * Let's see here price and the horsepower, defining the fuel type as columns, and it differentiated with number of cylinders
# * Also almost all the cars, the number of cylinder is four

# %%
fg = sns.FacetGrid(automobile_data_processed, 
                   col='fuel-type', 
                   height=7, aspect=1)

fg.map(sns.scatterplot, 'highway-mpg', 'price', s=100)

fg.add_legend()

# %%
fg = sns.FacetGrid(automobile_data_processed, 
                   col='fuel-type', 
                   hue='num-of-cylinders', 
                   height=7, aspect=1)

fg.map(sns.scatterplot, 'highway-mpg', 'price', s=100)

fg.add_legend()

# %%
tips_data = pd.read_csv('datasets/tips.csv')

tips_data.sample(10)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 79        17.29  2.71    Male     No  Thur   Lunch     2
# 143       27.05  5.00  Female     No  Thur   Lunch     6
# 151       13.13  2.00    Male     No   Sun  Dinner     2
# 109       14.31  4.00  Female    Yes   Sat  Dinner     2
# 179       34.63  3.55    Male    Yes   Sun  Dinner     2
# 204       20.53  4.00    Male    Yes  Thur   Lunch     4
# 47        32.40  6.00    Male     No   Sun  Dinner     4
# 176       17.89  2.00    Male    Yes   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# 231       15.69  3.00    Male    Yes   Sat  Dinner     3

# %%
plt.figure(figsize=(15,10))

fg = sns.FacetGrid(tips_data, 
                   col='size', 
                   height=7, aspect=1)

fg.map(plt.hist, 'total_bill', color='green')

plt.show()

# %%
fg = sns.FacetGrid(tips_data, 
                   row='time', 
                   height=6, aspect=1)

fg.map(sns.swarmplot, 'size', 'total_bill')

fg.add_legend()

# %%
fg = sns.FacetGrid(tips_data, 
                   col='time', 
                   hue='sex',
                   height=6, aspect=1)

fg.map(sns.swarmplot, 'size', 'total_bill')

fg.add_legend()
