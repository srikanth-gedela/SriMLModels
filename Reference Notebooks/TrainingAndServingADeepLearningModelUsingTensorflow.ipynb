# %%
import os
import sagemaker
#from sagemaker import get_execution_role
print(sagemaker.__version__)

sagemaker_session = sagemaker.Session()

#role = get_execution_role()
role = 'arn:aws:iam::776620588530:role/service-role/AmazonSageMaker-ExecutionRole-20210423T144098'
# Out:
# 2.38.0

# %%
role
# Out:
# 'arn:aws:iam::776620588530:role/service-role/AmazonSageMaker-ExecutionRole-20210423T144098'

# %%
region = sagemaker_session.boto_session.region_name

region
# Out:
# 'eu-west-2'

# %%
import os
import keras
import numpy as np
from keras.datasets import fashion_mnist

(x_train, y_train), (x_val, y_val) = fashion_mnist.load_data()

os.makedirs("./data", exist_ok = True)

np.savez('./data/training', image=x_train, label=y_train)
np.savez('./data/validation', image=x_val, label=y_val)

# %%
#training_data_uri = 's3://sagemaker-sample-data-{}/tensorflow/mnist'.format(region)

# %%
from sagemaker.tensorflow import TensorFlow

# %%
# Train on local data. S3 URIs would work too.
training_input_path   = 'file://data/training.npz'
validation_input_path = 'file://data/validation.npz'

# Store model locally. A S3 URI would work too.
output_path           = 'file:///tmp/model/'

# %%
mnist_estimator = TensorFlow(entry_point='mnist.py',
                             role=role,
                             instance_count=1,
                             instance_type='local',
                             framework_version='1.12',
                             py_version = 'py3',
                             output_path = output_path
                            )

# %%
mnist_estimator.fit(training_input_path)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-10-db57d52dadd7> in <module>
# ----> 1 mnist_estimator.fit(training_input_path)
#
# /usr/local/lib/python3.8/dist-packages/sagemaker/estimator.py in fit(self, inputs, wait, logs, job_name, experiment_config)
#     665
#     666         """
# --> 667         self._prepare_for_training(job_name=job_name)
#     668
#     669         self.latest_training_job = _TrainingJob.start_new(self, inputs, experiment_config)
#
# /usr/local/lib/python3.8/dist-packages/sagemaker/estimator.py in _prepare_for_training(self, job_name)
#    2201             self.code_uri = self.uploaded_code.s3_prefix
#    2202         else:
# -> 2203             self.uploaded_code = self._stage_user_code_in_s3()
#    2204             code_dir = self.uploaded_code.s3_prefix
#    2205             script = self.uploaded_code.script_name
#
# /usr/local/lib/python3.8/dist-packages/sagemaker/estimator.py in _stage_user_code_in_s3(self)
#    2263             kms_key = self.output_kms_key if code_bucket == output_bucket else None
#    2264
# -> 2265         return tar_and_upload_dir(
#    2266             session=self.sagemaker_session.boto_session,
#    2267             bucket=code_bucket,
#
# /usr/local/lib/python3.8/dist-packages/sagemaker/fw_utils.py in tar_and_upload_dir(session, bucket, s3_key_prefix, script, directory, dependencies, kms_key, s3_resource)
#     232     try:
#     233         source_files = _list_files_to_compress(script, directory) + dependencies
# --> 234         tar_file = sagemaker.utils.create_tar_file(
#     235             source_files, os.path.join(tmp, _TAR_SOURCE_FILENAME)
#     236         )
#
# /usr/local/lib/python3.8/dist-packages/sagemaker/utils.py in create_tar_file(source_files, target)
#     335         for sf in source_files:
#     336             # Add all files from the directory into the root of the directory structure of the tar
# --> 337             t.add(sf, arcname=os.path.basename(sf))
#     338     return filename
#     339
#
# /usr/lib/python3.8/tarfile.py in add(self, name, arcname, recursive, filter)
#    1951
#    1952         # Create a TarInfo object from the file.
# -> 1953         tarinfo = self.gettarinfo(name, arcname)
#    1954
#    1955         if tarinfo is None:
#
# /usr/lib/python3.8/tarfile.py in gettarinfo(self, name, arcname, fileobj)
#    1830         if fileobj is None:
#    1831             if not self.dereference:
# -> 1832                 statres = os.lstat(name)
#    1833             else:
#    1834                 statres = os.stat(name)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'mnist.py'

# %%
predictor = mnist_estimator.deploy(initial_instance_count=1, 
                                   instance_type='ml.p3.2xlarge',
                                   endpoint_name='image-classification-2019-09-03-05-58-51-313')
# Out:
# -------------------------------------------------------------------------------------!

# %%
import numpy as np

get_ipython().system('aws --region {region} s3 \
                     cp s3://sagemaker-sample-data-{region}/tensorflow/mnist/train_data.npy train_data.npy')

get_ipython().system('aws --region {region} s3 \
                     cp s3://sagemaker-sample-data-{region}/tensorflow/mnist/train_labels.npy train_labels.npy')
# Out:
# download: s3://sagemaker-sample-data-us-east-2/tensorflow/mnist/train_data.npy to ./train_data.npy
# download: s3://sagemaker-sample-data-us-east-2/tensorflow/mnist/train_labels.npy to ./train_labels.npy

# %%
train_data = np.load('train_data.npy')
train_labels = np.load('train_labels.npy')

# %%
predictions = predictor.predict(train_data[:50])

# %%
predictions
# Out:
# {'predictions': [{'probabilities': [1.80712e-05,
#     6.39894e-05,
#     0.00775659,
#     0.170431,
#     4.68211e-05,
#     9.73051e-05,
#     1.12912e-06,
#     0.724196,
#     0.0014382,
#     0.0959506],
#    'classes': 7},
#   {'probabilities': [6.56517e-07,
#     4.34871e-07,
#     7.03569e-05,
#     0.997957,
#     1.73637e-08,
#     0.000278024,
#     1.31928e-09,
#     5.45352e-07,
#     0.00121957,
#     0.000473886],
#    'classes': 3},
#   {'probabilities': [1.1415e-06,
#     3.30415e-06,
#     2.44502e-06,
#     8.65166e-05,
#     0.635296,
#     0.000732875,
#     3.43277e-06,
#     0.00414868,
#     0.00177787,
#     0.357948],
#    'classes': 4},
#   {'probabilities': [0.000224655,
#     8.24956e-06,
#     0.00254671,
#     1.7955e-06,
#     0.00109289,
#     0.000581131,
#     0.995533,
#     5.95401e-07,
#     3.33052e-06,
#     7.26739e-06],
#    'classes': 6},
#   {'probabilities': [1.02781e-05,
#     0.997066,
#     0.000640446,
#     9.79578e-05,
#     0.000121962,
#     6.84923e-05,
#     0.000597569,
#     0.000163621,
#     0.0012148,
#     1.85635e-05],
#    'classes': 1},
#   {'probabilities': [6.22158e-05,
#     9.18841e-07,
#     0.00063492,
#     0.0015131,
#     6.07317e-07,
#     0.000300428,
#     7.80547e-06,
#     7.51684e-08,
#     0.99736,
#     0.000120284],
#    'classes': 8},
#   {'probabilities': [6.72557e-06,
#     0.99766,
#     0.000259542,
#     4.99238e-05,
#     2.72132e-05,
#     1.22297e-05,
#     0.000157464,
#     6.0203e-05,
#     0.00176055,
#     6.45388e-06],
#    'classes': 1},
#   {'probabilities': [0.999969,
#     6.61264e-09,
#     1.6462e-05,
#     2.76216e-07,
#     1.06203e-07,
#     3.41249e-06,
#     6.84271e-06,
#     4.01156e-07,
#     2.61151e-07,
#     3.55001e-06],
#    'classes': 0},
#   {'probabilities': [8.49663e-06,
#     5.69321e-06,
#     3.10606e-05,
#     0.000141706,
#     0.0201635,
#     0.000278698,
#     4.71896e-06,
#     0.00111796,
#     0.000383887,
#     0.977864],
#    'classes': 9},
#   {'probabilities': [2.9448e-05,
#     8.62666e-07,
#     0.000631138,
#     0.000991577,
#     3.67169e-06,
#     0.000263271,
#     1.33158e-05,
#     3.18924e-08,
#     0.998019,
#     4.75297e-05],
#    'classes': 8},
#   {'probabilities': [0.999913,
#     8.39377e-09,
#     3.19091e-05,
#     6.06568e-07,
#     2.88261e-08,
#     3.8958e-05,
#     4.19633e-06,
#     4.41225e-07,
#     3.22328e-06,
#     7.22362e-06],
#    'classes': 0},
#   {'probabilities': [1.08174e-06,
#     2.08792e-06,
#     0.000928069,
#     0.998572,
#     2.316e-07,
#     0.000145238,
#     1.32977e-07,
#     3.28318e-08,
#     0.000348202,
#     3.29597e-06],
#    'classes': 3},
#   {'probabilities': [1.71882e-06,
#     0.998733,
#     0.000138106,
#     0.000441212,
#     0.000134237,
#     3.90716e-05,
#     4.69992e-05,
#     0.000176642,
#     0.000243975,
#     4.51368e-05],
#    'classes': 1},
#   {'probabilities': [0.250898,
#     3.40628e-05,
#     0.301339,
#     0.254439,
#     1.06433e-07,
#     0.173841,
#     5.88125e-07,
#     0.0175739,
#     0.00141034,
#     0.00046527],
#    'classes': 2},
#   {'probabilities': [2.87691e-06,
#     2.18226e-05,
#     0.000835315,
#     0.00588528,
#     0.00149277,
#     6.84505e-06,
#     2.29399e-07,
#     0.98621,
#     0.000180687,
#     0.00536397],
#    'classes': 7},
#   {'probabilities': [0.999796,
#     1.19096e-08,
#     0.000121912,
#     5.31372e-07,
#     2.76409e-07,
#     1.21811e-05,
#     5.20032e-05,
#     8.26033e-07,
#     2.71067e-06,
#     1.32175e-05],
#    'classes': 0},
#   {'probabilities': [1.85086e-07,
#     7.37254e-06,
#     0.999927,
#     3.82104e-05,
#     4.67653e-06,
#     3.19691e-07,
#     2.3647e-06,
#     6.31045e-06,
#     1.36563e-05,
#     1.51352e-07],
#    'classes': 2},
#   {'probabilities': [4.23131e-05,
#     5.00932e-08,
#     0.000231205,
#     8.0678e-05,
#     0.000125829,
#     1.89292e-06,
#     5.48784e-07,
#     0.00134676,
#     0.00164366,
#     0.996527],
#    'classes': 9},
#   {'probabilities': [0.000135821,
#     4.20119e-08,
#     0.000294718,
#     7.4692e-07,
#     6.94526e-05,
#     2.24921e-05,
#     0.999443,
#     5.13568e-10,
#     3.32938e-05,
#     8.88638e-07],
#    'classes': 6},
#   {'probabilities': [0.998929,
#     3.82596e-07,
#     0.00089106,
#     5.61471e-05,
#     1.30007e-08,
#     6.34234e-05,
#     4.31643e-06,
#     3.00924e-06,
#     3.49743e-07,
#     5.20579e-05],
#    'classes': 0},
#   {'probabilities': [7.44727e-05,
#     0.966998,
#     0.00311423,
#     0.00133502,
#     0.00121845,
#     0.00279433,
#     0.00676991,
#     0.000206428,
#     0.0173155,
#     0.000173629],
#    'classes': 1},
#   {'probabilities': [4.53196e-05,
#     3.97169e-05,
#     0.000103413,
#     2.03164e-06,
#     0.000645395,
#     0.000189508,
#     0.998973,
#     5.65456e-08,
#     1.27621e-06,
#     6.22795e-07],
#    'classes': 6},
#   {'probabilities': [1.00683e-06,
#     0.000516492,
#     0.00552245,
#     0.00473702,
#     5.29703e-05,
#     5.11556e-06,
#     1.80501e-07,
#     0.986018,
#     0.00301872,
#     0.000128026],
#    'classes': 7},
#   {'probabilities': [5.48537e-06,
#     0.998906,
#     0.000179208,
#     3.32926e-05,
#     4.63876e-05,
#     1.13265e-05,
#     0.000109488,
#     0.000113696,
#     0.000583438,
#     1.15815e-05],
#    'classes': 1},
#   {'probabilities': [2.99552e-05,
#     0.00312836,
#     0.00140345,
#     0.00973724,
#     0.107038,
#     0.0213563,
#     0.000350953,
#     0.00183686,
#     0.0273888,
#     0.82773],
#    'classes': 9},
#   {'probabilities': [0.000259772,
#     8.29622e-05,
#     0.000209045,
#     0.00192939,
#     0.000179407,
#     0.00081634,
#     1.81937e-07,
#     0.95109,
#     6.59173e-05,
#     0.0453667],
#    'classes': 7},
#   {'probabilities': [7.62241e-06,
#     2.7596e-06,
#     2.7524e-05,
#     2.10332e-07,
#     2.48109e-05,
#     0.00256707,
#     0.997323,
#     1.04039e-09,
#     4.65089e-05,
#     1.36376e-07],
#    'classes': 6},
#   {'probabilities': [2.53203e-05,
#     2.25558e-06,
#     1.88426e-07,
#     7.05769e-05,
#     3.29723e-06,
#     0.999451,
#     1.95615e-06,
#     3.32093e-06,
#     0.000428342,
#     1.38589e-05],
#    'classes': 5},
#   {'probabilities': [0.000128234,
#     1.47839e-06,
#     4.42361e-06,
#     0.00985176,
#     5.06786e-05,
#     0.948927,
#     9.18999e-07,
#     0.00024599,
#     0.000110475,
#     0.0406792],
#    'classes': 5},
#   {'probabilities': [0.000319378,
#     1.17938e-07,
#     3.30837e-05,
#     0.00328882,
#     3.47803e-06,
#     0.00565383,
#     4.11831e-07,
#     2.08642e-05,
#     0.977748,
#     0.0129317],
#    'classes': 8},
#   {'probabilities': [0.00233687,
#     0.00392637,
#     0.00131024,
#     0.0844396,
#     0.000163298,
#     0.00252038,
#     0.000202094,
#     0.00120474,
#     0.831472,
#     0.0724246],
#    'classes': 8},
#   {'probabilities': [8.60214e-07,
#     7.01973e-07,
#     7.46164e-05,
#     0.999098,
#     2.40871e-08,
#     0.000242955,
#     4.01452e-08,
#     2.88617e-09,
#     0.000580597,
#     2.74117e-06],
#    'classes': 3},
#   {'probabilities': [2.94584e-07,
#     0.000680319,
#     0.000420197,
#     0.00918273,
#     0.97505,
#     0.000432721,
#     2.65554e-05,
#     0.000136958,
#     0.0131893,
#     0.000881056],
#    'classes': 4},
#   {'probabilities': [9.04918e-07,
#     1.22691e-06,
#     8.78679e-07,
#     9.76884e-06,
#     0.970344,
#     0.000508473,
#     3.12922e-06,
#     0.000197795,
#     0.000298639,
#     0.0286348],
#    'classes': 4},
#   {'probabilities': [0.000322531,
#     1.51229e-07,
#     0.00451514,
#     0.000559053,
#     1.89634e-07,
#     9.45756e-06,
#     2.25336e-07,
#     1.37909e-06,
#     0.994546,
#     4.61857e-05],
#    'classes': 8},
#   {'probabilities': [2.42589e-06,
#     3.07842e-05,
#     0.00077165,
#     7.26336e-05,
#     0.0127373,
#     8.80494e-05,
#     2.70463e-05,
#     0.98069,
#     0.00132517,
#     0.0042546],
#    'classes': 7},
#   {'probabilities': [2.37703e-06,
#     3.13103e-05,
#     0.000361905,
#     0.999415,
#     2.60364e-08,
#     0.000121242,
#     2.2811e-09,
#     2.82203e-05,
#     3.05053e-06,
#     3.70857e-05],
#    'classes': 3},
#   {'probabilities': [0.000101363,
#     0.000273189,
#     0.000142865,
#     7.01159e-06,
#     2.98333e-05,
#     0.00198093,
#     0.996159,
#     3.32487e-08,
#     0.00130566,
#     6.46984e-08],
#    'classes': 6},
#   {'probabilities': [8.91454e-07,
#     5.63452e-05,
#     4.66069e-06,
#     0.000102525,
#     0.946409,
#     0.000248855,
#     2.43162e-06,
#     0.00403327,
#     0.000362915,
#     0.048779],
#    'classes': 4},
#   {'probabilities': [0.00018491,
#     1.43848e-05,
#     0.000109861,
#     1.90595e-06,
#     8.14709e-05,
#     0.0269106,
#     0.972595,
#     8.48174e-08,
#     9.94887e-05,
#     1.99276e-06],
#    'classes': 6},
#   {'probabilities': [4.41696e-05,
#     1.53166e-07,
#     6.89314e-06,
#     5.92904e-07,
#     1.03003e-05,
#     0.000417443,
#     0.999507,
#     8.70907e-10,
#     1.34249e-05,
#     4.25447e-07],
#    'classes': 6},
#   {'probabilities': [1.62742e-06,
#     4.09692e-07,
#     0.00479765,
#     0.993272,
#     4.2923e-08,
#     0.000267031,
#     3.30102e-09,
#     3.37619e-06,
#     0.00143755,
#     0.00021992],
#    'classes': 3},
#   {'probabilities': [0.00381799,
#     0.395533,
#     0.0127476,
#     0.14231,
#     0.000414702,
#     0.171406,
#     0.0948142,
#     1.55985e-05,
#     0.178253,
#     0.000688765],
#    'classes': 1},
#   {'probabilities': [4.79388e-05,
#     2.12375e-07,
#     0.000370593,
#     0.000810917,
#     4.42229e-06,
#     4.3154e-05,
#     3.27449e-06,
#     5.32685e-07,
#     0.998235,
#     0.000483513],
#    'classes': 8},
#   {'probabilities': [8.36144e-06,
#     3.51549e-08,
#     3.28411e-06,
#     2.57823e-05,
#     0.0061842,
#     0.000375029,
#     3.96573e-07,
#     0.00555729,
#     0.00114512,
#     0.9867],
#    'classes': 9},
#   {'probabilities': [0.00694412,
#     2.87714e-07,
#     0.000707403,
#     7.7889e-05,
#     0.000859784,
#     7.94794e-05,
#     8.9568e-05,
#     0.0402638,
#     0.00164366,
#     0.949334],
#    'classes': 9},
#   {'probabilities': [0.000349368,
#     1.4592e-05,
#     0.000149601,
#     0.000134674,
#     0.951965,
#     0.00077441,
#     0.000218981,
#     0.0033754,
#     0.000471631,
#     0.0425467],
#    'classes': 4},
#   {'probabilities': [0.000152314,
#     7.46095e-06,
#     0.000204991,
#     4.72922e-05,
#     0.96932,
#     0.000219486,
#     0.000181219,
#     0.000893165,
#     0.000604857,
#     0.0283688],
#    'classes': 4},
#   {'probabilities': [0.999781,
#     2.0205e-08,
#     5.32529e-05,
#     3.71599e-06,
#     1.0654e-08,
#     2.54364e-05,
#     2.21002e-07,
#     7.7307e-05,
#     2.96323e-06,
#     5.61398e-05],
#    'classes': 0},
#   {'probabilities': [5.85593e-05,
#     4.64522e-08,
#     1.2935e-06,
#     1.06586e-05,
#     1.42612e-05,
#     0.00012844,
#     1.64209e-07,
#     0.999152,
#     1.78598e-06,
#     0.000632742],
#    'classes': 7}]}

# %%
for i in range(0, 50):
    prediction = predictions['predictions'][i]['classes']
    label = train_labels[i]
    print('prediction is {}, label is {}, matched: {}'.format(prediction, label, prediction == label))
# Out:
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 2, label is 2, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 2, label is 2, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 1, label is 1, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 5, label is 5, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 8, label is 8, matched: True
# prediction is 7, label is 7, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 6, label is 6, matched: True
# prediction is 3, label is 3, matched: True
# prediction is 1, label is 8, matched: False
# prediction is 8, label is 8, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 9, label is 9, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 4, label is 4, matched: True
# prediction is 0, label is 0, matched: True
# prediction is 7, label is 7, matched: True
