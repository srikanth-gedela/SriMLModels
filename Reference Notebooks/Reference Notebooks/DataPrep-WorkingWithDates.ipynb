# %%
import pandas as pd
import numpy as np
import matplotlib
import datetime

import matplotlib.pyplot as plt

# %%
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %%
aapl = pd.read_csv('datasets/AAPL.csv')

aapl.head()
# Out:
#          Date       Open       High        Low      Close  Adj Close  \
# 0  2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 1  2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 2  2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 3  2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 4  2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#       Volume
# 0  174259400
# 1  103856900
# 2  130197200
# 3   85639400
# 4  131637800

# %%
aapl = aapl.sample(frac=1)

aapl.reset_index(inplace=True, drop=True)

aapl.head()
# Out:
#          Date        Open        High         Low       Close   Adj Close  \
# 0  2012-05-22   81.364288   81.982857   78.940002   79.567146   69.439308
# 1  2019-01-22  156.410004  156.729996  152.619995  153.300003  151.484207
# 2  2015-08-21  110.430000  111.900002  105.650002  105.760002   98.704018
# 3  2018-10-17  222.300003  222.639999  219.339996  221.190002  217.810089
# 4  2013-11-18   74.998573   75.312859   74.028572   74.089996   66.872269
#
#       Volume
# 0  173717600
# 1   30394000
# 2  128275500
# 3   22885400
# 4   61236000

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   object
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: float64(5), int64(1), object(1)
# memory usage: 124.0+ KB

# %%
aapl['Date'] = pd.to_datetime(aapl['Date'])

aapl.head()
# Out:
#         Date        Open        High         Low       Close   Adj Close  \
# 0 2012-05-22   81.364288   81.982857   78.940002   79.567146   69.439308
# 1 2019-01-22  156.410004  156.729996  152.619995  153.300003  151.484207
# 2 2015-08-21  110.430000  111.900002  105.650002  105.760002   98.704018
# 3 2018-10-17  222.300003  222.639999  219.339996  221.190002  217.810089
# 4 2013-11-18   74.998573   75.312859   74.028572   74.089996   66.872269
#
#       Volume
# 0  173717600
# 1   30394000
# 2  128275500
# 3   22885400
# 4   61236000

# %%
aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   datetime64[ns]
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 124.0 KB

# %%
aapl.shape
# Out:
# (2265, 7)

# %%
aapl.sort_values(by='Date', inplace=True)

aapl.head()
# Out:
#            Date       Open       High        Low      Close  Adj Close  \
# 619  2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 749  2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 762  2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 2164 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 1982 2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#          Volume
# 619   174259400
# 749   103856900
# 762   130197200
# 2164   85639400
# 1982  131637800

# %%
aapl.reset_index(inplace=True, drop=True)

aapl.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close     Volume
# 0 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463  174259400
# 1 2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864  103856900
# 2 2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719  130197200
# 3 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021   85639400
# 4 2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102  131637800

# %%
aapl['Date'] = aapl['Date'].apply(lambda d: d.to_pydatetime())

aapl.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2265 entries, 0 to 2264
# Data columns (total 7 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       2265 non-null   datetime64[ns]
#  1   Open       2265 non-null   float64
#  2   High       2265 non-null   float64
#  3   Low        2265 non-null   float64
#  4   Close      2265 non-null   float64
#  5   Adj Close  2265 non-null   float64
#  6   Volume     2265 non-null   int64
# dtypes: datetime64[ns](1), float64(5), int64(1)
# memory usage: 124.0 KB

# %%
aapl['Weekday'] = aapl['Date'].apply(lambda d: d.isoweekday())

aapl.head()
# Out:
#         Date       Open       High        Low      Close  Adj Close  \
# 0 2010-09-01  35.352856  35.922855  35.182858  35.761429  31.209463
# 1 2010-09-02  35.894287  36.024284  35.509998  36.024284  31.438864
# 2 2010-09-03  36.441429  36.968571  36.357143  36.967144  32.261719
# 3 2010-09-07  36.662857  37.075714  36.607143  36.830002  32.142021
# 4 2010-09-08  37.111427  37.770000  37.014286  37.560001  32.779102
#
#       Volume  Weekday
# 0  174259400        3
# 1  103856900        4
# 2  130197200        5
# 3   85639400        2
# 4  131637800        3

# %%
extract_year = lambda x: datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").year

# %%
aapl['Year'] = aapl['Date'].apply(extract_year)

aapl.sample(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1613 2017-01-30  120.930000  121.629997  120.660004  121.629997  116.537560
# 2192 2019-05-20  183.520004  184.350006  180.279999  183.089996  182.396988
# 593  2013-01-10   75.507141   75.531425   73.645714   74.787140   65.847328
# 1674 2017-04-27  143.919998  144.160004  143.309998  143.789993  138.367081
# 1011 2014-09-09   99.080002  103.080002   96.139999   97.989998   89.915321
# 311  2011-11-23   53.501427   53.691429   52.411430   52.427143   45.753868
# 946  2014-06-06   92.842857   93.037140   92.067146   92.224289   84.205879
# 766  2013-09-18   66.168571   66.621429   65.808571   66.382858   59.568172
# 1806 2017-11-02  166.600006  168.500000  165.279999  168.110001  163.075470
# 657  2013-04-15   61.000000   61.127144   59.935715   59.978573   53.116703
#
#          Volume  Weekday  Year
# 1613   30377500        1  2017
# 2192   38612300        1  2019
# 593   150286500        4  2013
# 1674   14246300        4  2017
# 1011  189846300        2  2014
# 311   107067800        3  2011
# 946    87484600        5  2014
# 766   114215500        3  2013
# 1806   41393400        4  2017
# 657    79380000        1  2013

# %%
extract_month = lambda x: datetime.datetime.strptime(str(x), "%Y-%m-%d %H:%M:%S").month

# %%
aapl['Month'] = aapl['Date'].apply(extract_month)

aapl.sample(10)
# Out:
#            Date        Open        High         Low       Close   Adj Close  \
# 1931 2018-05-04  178.250000  184.250000  178.169998  183.830002  179.695419
# 2    2010-09-03   36.441429   36.968571   36.357143   36.967144   32.261719
# 1796 2017-10-19  156.750000  157.080002  155.020004  155.979996  151.308716
# 538  2012-10-18   91.370003   91.722855   90.000000   90.377144   79.211945
# 1770 2017-09-13  159.869995  159.960007  157.910004  159.649994  154.868790
# 890  2014-03-18   75.128571   75.995712   75.028572   75.914284   68.928955
# 1049 2014-10-31  108.010002  108.040001  107.209999  108.000000   99.100471
# 1581 2016-12-12  113.290001  115.000000  112.489998  113.300003  108.556305
# 522  2012-09-26   95.534286   96.098572   94.457146   95.025711   83.286255
# 1162 2015-04-16  126.279999  127.099998  126.110001  126.169998  116.734108
#
#          Volume  Weekday  Year  Month
# 1931   56201300        5  2018      5
# 2     130197200        5  2010      9
# 1796   42584200        4  2017     10
# 538   119156100        4  2012     10
# 1770   44907400        3  2017      9
# 890    52411800        2  2014      3
# 1049   44639300        5  2014     10
# 1581   26374400        1  2016     12
# 522   144125800        3  2012      9
# 1162   28369000        4  2015      4

# %%
plt.figure(figsize=(10, 8))

plt.plot(aapl['Date'], 
         aapl['Close'])


plt.xlabel('Date')
plt.ylabel('AAPL stock price')

plt.show()

# %%
aapl_by_month = aapl.groupby(by='Month').mean()

aapl_by_month
# Out:
#              Open        High         Low       Close   Adj Close  \
# Month
# 1      101.994535  102.918907  100.951405  101.984114   95.751760
# 2      105.731883  106.824278  104.926416  105.957919   99.758569
# 3      110.966491  111.905912  109.954652  110.932645  104.567909
# 4      113.209677  114.178134  112.210968  113.190253  106.801941
# 5      114.985700  116.054071  114.072117  115.136299  109.015417
# 6      114.861189  115.727824  113.905445  114.763380  108.690969
# 7      118.451053  119.374985  117.628308  118.553113  112.321209
# 8      123.594762  124.837491  122.504158  123.739922  117.636038
# 9      106.138392  107.083427  105.041077  106.015301   99.328919
# 10     108.965033  110.002988  107.843502  108.991740  102.258505
# 11     106.816479  107.740888  105.663429  106.738062  100.328575
# 12     102.733191  103.636634  101.636406  102.549392   96.163693
#
#              Volume   Weekday         Year
# Month
# 1      7.937537e+07  3.109290  2015.016393
# 2      7.453773e+07  3.092486  2014.988439
# 3      7.219678e+07  3.010256  2014.979487
# 4      7.514483e+07  2.903226  2015.005376
# 5      6.305513e+07  3.103627  2015.020725
# 6      5.563672e+07  3.020942  2014.984293
# 7      5.575913e+07  2.957895  2015.010526
# 8      6.634713e+07  3.029851  2015.000000
# 9      8.456097e+07  3.114754  2013.967213
# 10     8.016695e+07  2.989848  2014.050761
# 11     7.033131e+07  2.962162  2014.000000
# 12     6.463759e+07  3.021277  2013.936170

# %%
plt.figure(figsize=(10, 8))

plt.plot(aapl_by_month.index, 
         aapl_by_month['Close'])


plt.xlabel('Date')
plt.ylabel('AAPL stock price')

plt.show()
